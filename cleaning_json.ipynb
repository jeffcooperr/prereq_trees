# %%
import pandas as pd

# %%
fall_data = pd.read_json("CS_fall_2025.json")
spring_data = pd.read_json("CS_spring_2026.json")

# %%
fall = pd.DataFrame(fall_data)

# %%
spring = pd.DataFrame(spring_data)

# %% [markdown]
# ### Removing Duplicate Courses

# %% [markdown]
# **Note that some courses have the same codes** *(independent studies, grad level courses, etc)*
# #### Keep only unique course titles rather than just codes

# %%
fall = fall.drop_duplicates(subset=["course_code", "title"])
spring = spring.drop_duplicates(subset=["course_code", "title"])

# %% [markdown]
# merge the two. should be 51 from fall, 59 from spring (110 total before dedupe)

# %%
all_courses = pd.concat([fall, spring], ignore_index=True)
all_courses = all_courses.sort_values(by="course_code").reset_index(drop=True)

# %% [markdown]
# ### Now if 2 courses match by code and title, this means they are offered in both semesters.
# #### Update the 'semester' of one to Fall & Spring, delete the other. Note 60 duplicates exist. 30 should be kept. new total should be 80

# %%
all_courses["semester"] = (
    all_courses.groupby(["title", "course_code"])["semester"]
    .transform(lambda x: "Fall and Spring 2026" if len(x) > 1 else x.iloc[0])
)

# %%
all_courses = all_courses.drop_duplicates(subset=["course_code", "title"])

# %% [markdown]
# ### NLP

# %% [markdown]
# #### adding 2 new fields to store course requirement information for graph building
# prerequisites: holds logical structure for storing required courses
# other_requirements: holds extra relevant qualitative information for given course
# uncertain: if the model is unsure of it's output for the first 2 fields

# %%
from dotenv import load_dotenv
import os
import openai

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
all_courses['prerequisites'] = None
all_courses['other_requirements'] = None
all_courses['uncertain'] = None

# %%
def extract_info(title, course_info):
    prompt = f"""
You are extracting structured prerequisite information from university course descriptions.

Rules for prerequisites:
- Represent prerequisites in JSON format using a nested AND/OR structure.
- If no prerequisites are listed, return null.
- Course codes must remain as strings, exactly as written (e.g., "MATH 2248").
- Only list valid course codes (e.g., "CS 1010", "MATH 2248") in the "prerequisites" field.
- Do NOT include any words, phrases, or text that are not course codes (e.g., "equivalent experience", "Junior standing").
- If a prerequisite is not a course code, move it to "other_requirements".
- Use this schema:
  - Single prerequisite: "CS 1010"
  - OR relationship: {{"OR": ["MATH 1010", "STAT 2010"]}}
  - AND relationship: {{"AND": ["MATH 1010", "CS 1210"]}}
  - Mixed logic: nest them, e.g.:
    {{"AND": ["MATH 2248", {{"OR": ["MATH 2522", "MATH 2544", "MATH 3201"]}}, "CS 1210"]}}
- "Recommended" courses are not prerequisites
- If the course information contains conflicting or ambiguous prerequisite information, 
still return the JSON, but also include a field "uncertain": true. 
Otherwise, set "uncertain": false.


Also extract "other_requirements" (like "Junior standing", "Department consent", "Open to degree and PACE students", "CS Majors Only") as a list of strings. If none, return [].

Return only valid JSON with two fields:
{{
  "prerequisites": ...,
  "other_requirements": ...,
  "uncertain": ...
}}

Now process this course description:

{course_info}
"""
    completion = client.chat.completions.create(
        model="gpt-4o-mini",  # Cheap and fast model
        messages=[{"role": "user", "content": prompt}],
        temperature=0,  # For consistency
        response_format={"type": "json_object"}
    )
    print("Completed: ", course_info[:15],"-", title)
    return json.loads(completion.choices[0].message.content)

# %%
from openai import OpenAI
client = OpenAI()
import json

# %%
for idx, row in all_courses.iterrows():
    course_description = f"""Course: {row['course_code']} - {row['title']} Description: {row['description']} More Description: {row['section_description']} Section Expectations: {row['section_expectations']} Evaluation: {row['evaluation']} SOC Comments: {row['soc_comments']}"""
    title = row['title']
    result = extract_info(title, course_description)
    all_courses.at[idx, "prerequisites"] = result.get("prerequisites")
    all_courses.at[idx, "other_requirements"] = result.get("other_requirements")
    all_courses.at[idx, "uncertain"] = result.get("uncertain", False)
# Out:
# Completed:  Course: CS 1080 - Intro to Web Site Dev
# Completed:  Course: CS 1210 - Comp Prog I: for CS majors
# Completed:  Course: CS 1210 - Computer Programming I
# Completed:  Course: CS 1320 - Puzzles, Games & Algorithms
# Completed:  Course: CS 1500 - Seminar for New CS Majors
# Completed:  Course: CS 1640 - Discrete Structures
# Completed:  Course: CS 1870 - Intro to Data Science
# Completed:  Course: CS 1994 - Teaching Assistantship
# Completed:  Course: CS 2100 - Intermediate Programming
# Completed:  Course: CS 2210 - Computer Organization
# Completed:  Course: CS 2240 - Data Struc & Algorithms
# Completed:  Course: CS 2250 - Computability& Complexity
# Completed:  Course: CS 2300 - Advanced Programming
# Completed:  Course: CS 2500 - Intro to Database Systems
# Completed:  Course: CS 2510 - Intro Artificial Intelligence
# Completed:  Course: CS 2660 - Cybersecurity Principles
# Completed:  Course: CS 2870 - Basics of Data Science
# Completed:  Course: CS 2920 - SL:Girls Who Code
# Completed:  Course: CS 2993 - Independent Study
# Completed:  Course: CS 2994 - Teaching Assistantship
# Completed:  Course: CS 3010 - Operating Systems
# Completed:  Course: CS 3040 - Database Systems
# Completed:  Course: CS 3050 - Software Engineering
# Completed:  Course: CS 3060 - Evolutionary Robotics
# Completed:  Course: CS 3110 - Data Privacy
# Completed:  Course: CS 3120 - Secure Distributed Computation
# Completed:  Course: CS 3220 - Computer Architecture
# Completed:  Course: CS 3240 - Algorithm Design & Analysis
# Completed:  Course: CS 3250 - Programming Languages
# Completed:  Course: CS 3280 - Human-Computer Interaction
# Completed:  Course: CS 3540 - Machine Learning
# Completed:  Course: CS 3650 - Computer Networks
# Completed:  Course: CS 3737 - Intro to Numerical Analysis
# Completed:  Course: CS 3750 - Mobile App Development
# Completed:  Course: CS 3870 - Data Science I - Pinnacle
# Completed:  Course: CS 3920 - Senior Seminar
# Completed:  Course: CS 3930 - Computing Career Preparation
# Completed:  Course: CS 3993 - IS:Intro to React
# Completed:  Course: CS 3993 - IS: Bioinformatics
# Completed:  Course: CS 3993 - IS:FullstackWebApplication Dev
# Completed:  Course: CS 3993 - Independent Study
# Completed:  Course: CS 3993 - IS:Comp Social Science
# Completed:  Course: CS 3993 - IS:Graph Editing Algorithms
# Completed:  Course: CS 3994 - Teaching Assistantship
# Completed:  Course: CS 4996 - Undergraduate Honors Thesis
# Completed:  Course: CS 5040 - Gr Database Systems
# Completed:  Course: CS 5060 - Advanced Evolutionary Robotics
# Completed:  Course: CS 5110 - Advanced Data Privacy
# Completed:  Course: CS 5120 - Adv Secure Distributed Comput
# Completed:  Course: CS 5220 - Advanced Computer Architecture
# Completed:  Course: CS 5240 - Advanced Algorithm Design
# Completed:  Course: CS 5540 - Advanced Machine Learning
# Completed:  Course: CS 5870 - Data Science I - Experience
# Completed:  Course: CS 5990 - Natural Language Processing
# Completed:  Course: CS 6020 - Modeling Complex Systems I
# Completed:  Course: CS 6021 - Modeling Complex Systems II
# Completed:  Course: CS 6040 - Data Mining
# Completed:  Course: CS 6391 - Master's Thesis Research
# Completed:  Course: CS 6392 - GPU-Accelerated RGs
# Completed:  Course: CS 6392 - Master's Project Research
# Completed:  Course: CS 6540 - Deep Learning
# Completed:  Course: CS 6550 - Usable Privacy and Security
# Completed:  Course: CS 6990 - Computer Security Foundations
# Completed:  Course: CS 6990 - Mind, Morphology, and Machine
# Completed:  Course: CS 6990 - Quantum Computing
# Completed:  Course: CS 6993 - IS:MechanisticInterpretability
# Completed:  Course: CS 7491 - Doctoral Dissertation Research

# %%
# row = all_courses.iloc[0]
# course_description = f"""Course: {row['course_code']} - {row['title']} Description: {row['description']} More Description: {row['section_description']} Section Expectations: {row['section_expectations']} Evaluation: {row['evaluation']} SOC Comments: {row['soc_comments']}"""
# title = row['title']
# result = extract_info(title, course_description)

# %%
for idx, row in all_courses.iterrows():
    print(f'{row['course_code']} - {row['title']} | Prereqs: {row['prerequisites']}')
# Out:
# CS 1080 - Intro to Web Site Dev | Prereqs: None
# CS 1210 - Comp Prog I: for CS majors | Prereqs: None
# CS 1210 - Computer Programming I | Prereqs: None
# CS 1320 - Puzzles, Games & Algorithms | Prereqs: None
# CS 1500 - Seminar for New CS Majors | Prereqs: None
# CS 1640 - Discrete Structures | Prereqs: {'AND': [{'OR': ['CS 1210', 'CS 2100']}, {'OR': ['MATH 1234', 'MATH 1242']}]}
# CS 1870 - Intro to Data Science | Prereqs: None
# CS 1994 - Teaching Assistantship | Prereqs: None
# CS 2100 - Intermediate Programming | Prereqs: CS 1210
# CS 2210 - Computer Organization | Prereqs: CS 2100
# CS 2240 - Data Struc & Algorithms | Prereqs: {'AND': ['CS 2100']}
# CS 2250 - Computability& Complexity | Prereqs: {'OR': ['CS 1640', 'MATH 2055']}
# CS 2300 - Advanced Programming | Prereqs: CS 2240
# CS 2500 - Intro to Database Systems | Prereqs: {'AND': ['CS 1210']}
# CS 2510 - Intro Artificial Intelligence | Prereqs: CS 2240
# CS 2660 - Cybersecurity Principles | Prereqs: CS 2210
# CS 2870 - Basics of Data Science | Prereqs: {'OR': ['STAT 1110', 'STAT 1410', 'STAT 2430']}
# CS 2920 - SL:Girls Who Code | Prereqs: None
# CS 2994 - Teaching Assistantship | Prereqs: None
# CS 3010 - Operating Systems | Prereqs: {'AND': ['CS 2300', 'CS 2210']}
# CS 3040 - Database Systems | Prereqs: CS 2240
# CS 3050 - Software Engineering | Prereqs: CS 2300
# CS 3060 - Evolutionary Robotics | Prereqs: None
# CS 3110 - Data Privacy | Prereqs: {'AND': ['CS 2240', 'CS 2250']}
# CS 3120 - Secure Distributed Computation | Prereqs: {'AND': ['CS 2240', 'CS 2250']}
# CS 3220 - Computer Architecture | Prereqs: {'OR': ['CMPE 2210', 'CS 2210']}
# CS 3240 - Algorithm Design & Analysis | Prereqs: CS 2240
# CS 3250 - Programming Languages | Prereqs: {'AND': ['CS 2240', 'CS 2250']}
# CS 3280 - Human-Computer Interaction | Prereqs: {'OR': ['CS 1080']}
# CS 3540 - Machine Learning | Prereqs: {'AND': [{'OR': ['STAT 2510', 'STAT 5510']}, {'OR': ['MATH 2522', 'MATH 2544']}]}
# CS 3650 - Computer Networks | Prereqs: CS 2240
# CS 3737 - Intro to Numerical Analysis | Prereqs: {'AND': ['MATH 2248', {'OR': ['MATH 2522', 'MATH 2544', 'MATH 3201']}, 'CS 1210']}
# CS 3750 - Mobile App Development | Prereqs: {'AND': ['CS 2300']}
# CS 3870 - Data Science I - Pinnacle | Prereqs: {'AND': ['CS 1210', {'OR': ['STAT 1410', 'STAT 2430']}, 'CS 2100', {'OR': ['MATH 2522', 'MATH 2544']}]}
# CS 3920 - Senior Seminar | Prereqs: None
# CS 3930 - Computing Career Preparation | Prereqs: CS 2240
# CS 3993 - IS:Intro to React | Prereqs: None
# CS 3993 - IS: Bioinformatics | Prereqs: None
# CS 3993 - IS:FullstackWebApplication Dev | Prereqs: None
# CS 3993 - IS:Comp Social Science | Prereqs: None
# CS 3993 - IS:Graph Editing Algorithms | Prereqs: None
# CS 3994 - Teaching Assistantship | Prereqs: None
# CS 4996 - Undergraduate Honors Thesis | Prereqs: None
# CS 5040 - Gr Database Systems | Prereqs: None
# CS 5060 - Advanced Evolutionary Robotics | Prereqs: None
# CS 5110 - Advanced Data Privacy | Prereqs: None
# CS 5120 - Adv Secure Distributed Comput | Prereqs: None
# CS 5220 - Advanced Computer Architecture | Prereqs: None
# CS 5240 - Advanced Algorithm Design | Prereqs: None
# CS 5540 - Advanced Machine Learning | Prereqs: {'AND': ['STAT 2510', {'OR': ['MATH 2522', 'MATH 2544']}]}
# CS 5870 - Data Science I - Experience | Prereqs: {'AND': ['CS 1210', {'OR': ['STAT 1410', 'STAT 2430']}]}
# CS 5990 - Natural Language Processing | Prereqs: None
# CS 6020 - Modeling Complex Systems I | Prereqs: None
# CS 6021 - Modeling Complex Systems II | Prereqs: {'OR': ['CS 6020', 'CSYS 6020']}
# CS 6040 - Data Mining | Prereqs: None
# CS 6391 - Master's Thesis Research | Prereqs: None
# CS 6392 - GPU-Accelerated RGs | Prereqs: None
# CS 6392 - Master's Project Research | Prereqs: None
# CS 6540 - Deep Learning | Prereqs: CS 3540
# CS 6550 - Usable Privacy and Security | Prereqs: None
# CS 6990 - Computer Security Foundations | Prereqs: None
# CS 6990 - Mind, Morphology, and Machine | Prereqs: None
# CS 6990 - Quantum Computing | Prereqs: None
# CS 6993 - IS:MechanisticInterpretability | Prereqs: None
# CS 7491 - Doctoral Dissertation Research | Prereqs: None

# %%
# all_courses[0:50][['title', 'prerequisites', 'other_requirements']]
# all_courses[0:50][['title', 'prerequisites', 'other_requirements']].to_csv("preview.csv", index=False)

# %%
all_courses[0:50]
# Out:
#    course_code                 section                           title  \
# 0      CS 1080    Section A, CRN 91695           Intro to Web Site Dev
# 2      CS 1210    Section F, CRN 92166      Comp Prog I: for CS majors
# 3      CS 1210    Section B, CRN 90147          Computer Programming I
# 5      CS 1320    Section A, CRN 94171     Puzzles, Games & Algorithms
# 7      CS 1500    Section A, CRN 90913       Seminar for New CS Majors
# 8      CS 1640    Section A, CRN 90230             Discrete Structures
# 9      CS 1870    Section A, CRN 92324           Intro to Data Science
# 10     CS 1994                     NaN          Teaching Assistantship
# 12     CS 2100                     NaN        Intermediate Programming
# 14     CS 2210                     NaN           Computer Organization
# 16     CS 2240                     NaN         Data Struc & Algorithms
# 18     CS 2250                     NaN       Computability& Complexity
# 20     CS 2300                     NaN            Advanced Programming
# 22     CS 2500    Section A, CRN 94648       Intro to Database Systems
# 24     CS 2510                     NaN   Intro Artificial Intelligence
# 26     CS 2660  Section OL1, CRN 13197        Cybersecurity Principles
# 27     CS 2870                     NaN          Basics of Data Science
# 28     CS 2920    Section A, CRN 12182               SL:Girls Who Code
# 30     CS 2993                     NaN               Independent Study
# 31     CS 2994                     NaN          Teaching Assistantship
# 33     CS 3010    Section A, CRN 90238               Operating Systems
# 35     CS 3040    Section A, CRN 93083                Database Systems
# 36     CS 3050    Section A, CRN 11825            Software Engineering
# 37     CS 3060    Section A, CRN 10577           Evolutionary Robotics
# 38     CS 3110    Section A, CRN 92684                    Data Privacy
# 39     CS 3120    Section A, CRN 15536  Secure Distributed Computation
# 40     CS 3220    Section A, CRN 10129           Computer Architecture
# 41     CS 3240                     NaN     Algorithm Design & Analysis
# 43     CS 3250    Section A, CRN 95707           Programming Languages
# 44     CS 3280    Section A, CRN 95641      Human-Computer Interaction
# 45     CS 3540    Section A, CRN 94179                Machine Learning
# 47     CS 3650    Section A, CRN 15379               Computer Networks
# 48     CS 3737    Section A, CRN 93742     Intro to Numerical Analysis
# 49     CS 3750    Section A, CRN 90889          Mobile App Development
# 50     CS 3870    Section A, CRN 92312       Data Science I - Pinnacle
# 52     CS 3920                     NaN                  Senior Seminar
# 54     CS 3930    Section A, CRN 92314    Computing Career Preparation
# 56     CS 3993    Section A, CRN 96402               IS:Intro to React
# 57     CS 3993    Section B, CRN 96455              IS: Bioinformatics
# 58     CS 3993    Section C, CRN 96485  IS:FullstackWebApplication Dev
# 59     CS 3993    Section D, CRN 96517               Independent Study
# 60     CS 3993    Section E, CRN 96530          IS:Comp Social Science
# 61     CS 3993    Section F, CRN 96531     IS:Graph Editing Algorithms
# 62     CS 3994    Section A, CRN 14971          Teaching Assistantship
# 64     CS 4996                     NaN     Undergraduate Honors Thesis
# 65     CS 5040    Section A, CRN 94078             Gr Database Systems
# 66     CS 5060    Section A, CRN 13202  Advanced Evolutionary Robotics
# 67     CS 5110    Section A, CRN 93798           Advanced Data Privacy
# 68     CS 5120    Section A, CRN 15537   Adv Secure Distributed Comput
# 69     CS 5220    Section A, CRN 13210  Advanced Computer Architecture
#
#          credit_hours                                       meeting_info  \
# 0                   3  TTh 4:25pm-5:40pm in JAMES M JEFFORDS HALL 127...
# 2                   3  TTh 2:50pm-4:05pm in MARSH LIFE SCI 105 (8/25 ...
# 3                   3  TTh 8:30am-9:45am in VOTEY BLDG 207 (8/25 to 1...
# 5                   3  MWF 10:50am-11:40am in VOTEY BLDG 303 (8/25 to...
# 7                   1   F 2:20pm-3:10pm in VOTEY BLDG 105 (8/25 to 12/5)
# 8                   3  MWF 1:10pm-2pm in PERKINS BUILDING 003 (8/25 t...
# 9                   3    MWF 1:10pm-2pm in VOTEY BLDG 209 (8/25 to 12/5)
# 10  Varies by section                                                NaN
# 12  Varies by section                                                NaN
# 14                  3                                                NaN
# 16                  3                                                NaN
# 18                  3                                                NaN
# 20                  3                                                NaN
# 22                  3  MW 3:30pm-4:45pm in INNOVATION HALL E204 (8/25...
# 24                  3                                                NaN
# 26                  3                                                NaN
# 27                  3                                                NaN
# 28                  1                                                NaN
# 30  Varies by section                                                NaN
# 31             1 to 3                                                NaN
# 33                  3  MWF 12pm-12:50pm in VOTEY BLDG 207 (8/25 to 12/5)
# 35                  3  MWF 8:30am-9:20am in MARSH LIFE SCI 105 (8/25 ...
# 36                  3         MWF 3:30pm-4:20pm UNASSIGNED (1/12 to 5/1)
# 37                  3         TTh 8:30am-9:45am UNASSIGNED (1/12 to 5/1)
# 38                  3    MWF 1:10pm-2pm in DEWEY HALL 314 (8/25 to 12/5)
# 39                  3       MWF 10:50am-11:40am UNASSIGNED (1/12 to 5/1)
# 40                  3            MWF 1:10pm-2pm UNASSIGNED (1/12 to 5/1)
# 41                  3                                                NaN
# 43                  3  TTh 4:25pm-5:40pm in INNOVATION HALL E210 (8/2...
# 44                  3  TTh 1:15pm-2:30pm in LAFAYETTE HALL L111 (8/25...
# 45                  3  TTh 1:15pm-2:30pm in VOTEY BLDG 207 (8/25 to 1...
# 47                  3         TTh 2:50pm-4:05pm UNASSIGNED (1/12 to 5/1)
# 48                  3  TTh 2:50pm-4:05pm in PERKINS BUILDING 102 (8/2...
# 49                  3  MWF 3:30pm-4:20pm in JAMES M JEFFORDS HALL 112...
# 50                  3  TTh 4:25pm-5:40pm in INNOVATION HALL E430 (8/2...
# 52                  1                                                NaN
# 54                  1  W 5:05pm-5:55pm in MORRILL HALL 010 (8/25 to 1...
# 56                  2  T 8:30am-9:20am in ON CAMPUS SEE NOTES (8/25 t...
# 57            1 to 18                                                NaN
# 58                  3                                                NaN
# 59                  3                                                NaN
# 60                  3                                                NaN
# 61                  3  M 8:30am-9:20am in ON CAMPUS SEE NOTES (8/25 t...
# 62                  1                                                NaN
# 64                  3                                                NaN
# 65                  3  MWF 8:30am-9:20am in MARSH LIFE SCI 105 (8/25 ...
# 66                  3         TTh 8:30am-9:45am UNASSIGNED (1/12 to 5/1)
# 67                  3    MWF 1:10pm-2pm in DEWEY HALL 314 (8/25 to 12/5)
# 68                  3       MWF 10:50am-11:40am UNASSIGNED (1/12 to 5/1)
# 69                  3            MWF 1:10pm-2pm UNASSIGNED (1/12 to 5/1)
#
#                  instructor  \
# 0              Murat Gungor
# 2             Sami Connolly
# 3             Sami Connolly
# 5                 Lisa Dion
# 7             Sami Connolly
# 8            Jeffrey Jewell
# 9              Roger Tenore
# 10                      NaN
# 12            Jackie Horton
# 14          Clayton Cafiero
# 16                      NaN
# 18                      NaN
# 20                Lisa Dion
# 22            Jackie Horton
# 24          Clayton Cafiero
# 26               James Eddy
# 27             Jacob Martin
# 28                Lisa Dion
# 30                      NaN
# 31                      NaN
# 33           Jason Hibbeler
# 35                Byung Lee
# 36           Jason Hibbeler
# 37           Joshua Bongard
# 38                 Joe Near
# 39                 Joe Near
# 40           Jason Hibbeler
# 41                      NaN
# 43          Jennifer Paykin
# 44            Yuanyuan Feng
# 45             Safwan Wshah
# 47             Chris Skalka
# 48                   Jun Yu
# 49           Jason Hibbeler
# 50            Alice Patania
# 52                Lisa Dion
# 54              Jill Duprey
# 56          Clayton Cafiero
# 57  Laurent Hebert-Dufresne
# 58          Clayton Cafiero
# 59                Lisa Dion
# 60           Chris Danforth
# 61           Brian Lavallee
# 62            Jackie Horton
# 64                      NaN
# 65                Byung Lee
# 66           Joshua Bongard
# 67                 Joe Near
# 68                 Joe Near
# 69           Jason Hibbeler
#
#                                           description  \
# 0   Provides a strong foundation in HTML, CSS, ima...
# 2   Introduction to algorithmic problem solving an...
# 3   Introduction to algorithmic problem solving an...
# 5   Introductory computer science through explorat...
# 7   A fun and accessible breadth-first introductio...
# 8   Introduction to analytic and formal methods of...
# 9   Basic techniques of data harvesting and cleani...
# 10  Assist in instruction of undergraduate compute...
# 12  Intermediate programming concepts including co...
# 14  Introduction to computer system organization i...
# 16  Design and implementation of linear structures...
# 18  Formal languages and expressiveness. Turing co...
# 20  Builds programming maturity and proficiency th...
# 22  Serves as a foundational course in modern data...
# 24  An introduction to artificial intelligence inc...
# 26  Introduction to cybersecurity, fundamental sec...
# 27  Basic data science techniques, from import to ...
# 28  Service learning experience that benefits the ...
# 30  A course which is tailored to fit the interest...
# 31  Undergraduate student service as a teaching as...
# 33  Supervisory and control software for multiprog...
# 35  Techniques for processing very large collectio...
# 36  Treatment of software engineering problems and...
# 37  Exploration of the automated design of autonom...
# 38  Explores the research field of data privacy, i...
# 39  Techniques for secure computation involving mu...
# 40  Architecture of computing systems. Control uni...
# 41  Comprehensive study of algorithms including gr...
# 43  Principles of programming language design and ...
# 44  Covers the foundational theories and methods i...
# 45  Introduction to machine learning algorithms, t...
# 47  Introduction to the theoretical and pragmatic ...
# 48  Error analysis, root-finding, interpolation, l...
# 49  A projects-based course focusing on software d...
# 50  Data harvesting, cleaning, and summarizing; wo...
# 52  Oral presentations that pertain to the ethical...
# 54  Seminar to help students develop necessary ski...
# 56  A course which is tailored to fit the interest...
# 57  A course which is tailored to fit the interest...
# 58  A course which is tailored to fit the interest...
# 59  A course which is tailored to fit the interest...
# 60  A course which is tailored to fit the interest...
# 61  A course which is tailored to fit the interest...
# 62  Undergraduate student service as a teaching as...
# 64  College honors thesis or other department/prog...
# 65  Covers the theory and practice of database des...
# 66  Explores the automated design of autonomous ma...
# 67  Explores the research field of data privacy, i...
# 68  Techniques for secure computation involving mu...
# 69  Provides a thorough and sophisticated examinat...
#
#                                   section_description  \
# 0   Lays a foundation in website coding with HTML,...
# 2   Introduction to programming and computer scien...
# 3            Introduction to programming with Python.
# 5   In this course, you will explore computational...
# 7   This course is intended to introduce new Compu...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  You will learn the common data structures for ...
# 18                                                NaN
# 20  This project-based course is separated into fo...
# 22  This course will serve as a foundational cours...
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  This is for students who help facilitate the U...
# 30                                                NaN
# 31                                                NaN
# 33  CS 3010 will provide a broad overview of opera...
# 35  Theory and practice of database design and app...
# 36  CS 3050 will present a broad overview of the m...
# 37                                                NaN
# 38  How can we learn from sensitive data collected...
# 39  Techniques for secure computation involving mu...
# 40  CS 3220 will provide a thorough and sophistica...
# 41                                                NaN
# 43  The focus of this course is on the design of p...
# 44  This course fulfills WIL2 (Writing and Informa...
# 45  This course offers an introduction to advanced...
# 47  Description: Introduction to the theoretical a...
# 48  This course covers introductory materials on n...
# 49  CS 3750 will provide a broad overview of iOS a...
# 50                                                NaN
# 52  This course explores ethics at the intersectio...
# 54                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Theory and practice of database design and app...
# 66                                                NaN
# 67  How can we learn from sensitive data collected...
# 68  Techniques for secure computation involving mu...
# 69  CS 5220 will provide a thorough and sophistica...
#
#                                  section_expectations  \
# 0       Assumes no prior experience with programming.
# 2   Assumes no prior experience with programming. ...
# 3       Assumes no prior experience with programming.
# 5   This course is taught in an active learning st...
# 7   You will be expected to attend each lecture pe...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  This class is run lecture-style with practice ...
# 18                                                NaN
# 20  Every three-week module will be themed and wil...
# 22          Completion of CS1210. Sophomore Standing.
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  You will be expected to attend the club every ...
# 30                                                NaN
# 31                                                NaN
# 33  Students will learn concepts by creating sever...
# 35  Lecture course. 6 to 8 hours of work expected ...
# 36  There will be three individual in-class coding...
# 37                                                NaN
# 38  This course will be structured around lectures...
# 39  By the end of this course, you will be able to...
# 40  Students will do written exercises; create sof...
# 41                                                NaN
# 43  Prerequisites: CS 2240, CS 2250. The main cour...
# 44  The course materials include:\nTextbook: Norma...
# 45  Weekly assignments, Term Project and two Mid-t...
# 47  This course is taught in a lecture and discuss...
# 48  This course is in lecture format. Homework (or...
# 49  The instructor will discuss and elaborate on t...
# 50                                                NaN
# 52  You will be expected to attend class regularly...
# 54                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Lecture course. 6 to 8 hours of work expected ...
# 66                                                NaN
# 67  This course will be structured around lectures...
# 68  By the end of this course, you will be able to...
# 69  Students will do written exercises; create sof...
#
#                                            evaluation  \
# 0   Quizzes, Active Learning Exercises, Lab Exerci...
# 2                                                 NaN
# 3   Weekly homework, lab and active learning exerc...
# 5   This course is taught using a points-based sys...
# 7   Your final grade will be based on pre-class wr...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  Your final grade will be based on quizzes, pro...
# 18                                                NaN
# 20  This course uses a point-based grading system,...
# 22                                                NaN
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  You will be evaluated based on attendance, com...
# 30                                                NaN
# 31                                                NaN
# 33  Course grades will be based on the midterm and...
# 35  Weekly homework, including written and program...
# 36  Course grades will be based on in-class coding...
# 37                                                NaN
# 38  Your grade for the course will be determined a...
# 39  Your grade for the course will be determined a...
# 40  Student grades will be based on the exams, the...
# 41                                                NaN
# 43  Homework for the course will be a combination ...
# 44  Evaluations:\nStudent grades will be based on:...
# 45  • Assigned homework (30%)\n• Term Project (30%...
# 47  - Homework and programming assigments: 60%\n -...
# 48  Grades are based on midterm and final exams, q...
# 49  Student grades will be based on the individual...
# 50                                                NaN
# 52  Grading is based on participating in debates a...
# 54                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Weekly homework, including written and program...
# 66                                                NaN
# 67  Your grade for the course will be determined a...
# 68  Your grade for the course will be determined a...
# 69  Student grades will be based on the exams, the...
#
#                                          soc_comments              semester  \
# 0                    Open to Degree and PACE students  Fall and Spring 2025
# 2                Open to CS, CSIS, and DS majors only             Fall 2025
# 3                    Open to Degree and PACE students  Fall and Spring 2025
# 5                    Open to Degree and PACE students  Fall and Spring 2025
# 7               CS, CSIS, or Data Science majors only             Fall 2025
# 8   Prereqs enforced by the system: (CS 1210 or 21...             Fall 2025
# 9   Cross-listed with STAT 1870 A;\nTotal combined...             Fall 2025
# 10                                  Varies by section  Fall and Spring 2025
# 12                                  Varies by section  Fall and Spring 2025
# 14                                  Varies by section  Fall and Spring 2025
# 16                                  Varies by section  Fall and Spring 2025
# 18  Prereqs enforced by the system: CS 1640 or MAT...  Fall and Spring 2025
# 20  Prereqs enforced by the system: CS 2240;\nOpen...  Fall and Spring 2025
# 22  Prereqs enforced by the system: CS 1210\nOpen ...  Fall and Spring 2025
# 24            Prereqs enforced by the system: CS 2240  Fall and Spring 2025
# 26  Prereqs enforced by the system: CS 2210 with a...           Spring 2026
# 27                                  Varies by section             Fall 2025
# 28  Instructor permission required;\nOpen to Degre...  Fall and Spring 2025
# 30                                  Varies by section             Fall 2025
# 31                                  Varies by section  Fall and Spring 2025
# 33  Prereqs enforced by the system: CS 2210 and CS...  Fall and Spring 2025
# 35  Prereqs enforced by the system: CS 2240;\nColo...             Fall 2025
# 36  Prereqs enforced by the system: CS 2300;\nProj...           Spring 2026
# 37  Prereq: Junior standing and programming experi...           Spring 2026
# 38  Prereqs enforced by the system: CS 2240 and CS...             Fall 2025
# 39  Prereqs enforced by the system: CS 2240 and CS...           Spring 2026
# 40  Prereqs enforced by the system: CS 2210 or CMP...           Spring 2026
# 41                                  Varies by section  Fall and Spring 2025
# 43  Prereqs enforced by the system: CS 2240, CS 22...             Fall 2025
# 44  Prereq: CS 1080 or equivalent experience;\nmin...             Fall 2025
# 45  Prereqs enforced by the system: STAT 2510 or 5...  Fall and Spring 2025
# 47  Cross-listed with CMPE 3650 A; Total combined ...           Spring 2026
# 48  Prereqs enforced by the system: CS 1210 and MA...             Fall 2025
# 49  Prereqs enforced by the system: CS 2300;\nOpen...             Fall 2025
# 50  Prereqs enforced by the system: CS 1210 and\n(...  Fall and Spring 2025
# 52                    CS or CSIS senior students only  Fall and Spring 2025
# 54            Prereqs enforced by the system: CS 2240  Fall and Spring 2025
# 56                                                NaN             Fall 2025
# 57  This course is a tailored project for a specif...             Fall 2025
# 58                                                NaN             Fall 2025
# 59                     Instructor permission required             Fall 2025
# 60                                                NaN             Fall 2025
# 61                     Instructor permission required             Fall 2025
# 62                                                NaN  Fall and Spring 2025
# 64                                  Varies by section             Fall 2025
# 65  Colocated with CS 3040 A;\nTotal combined enro...             Fall 2025
# 66  Graduate students only;\nCo-located with CS 30...           Spring 2026
# 67  Prereq: Graduate student;\nCo-located with CS ...             Fall 2025
# 68  Familiarity with topics of data structures and...           Spring 2026
# 69  Familiarity with topics of computer organizati...           Spring 2026
#
#                                         prerequisites  \
# 0                                                None
# 2                                                None
# 3                                                None
# 5                                                None
# 7                                                None
# 8   {'AND': [{'OR': ['CS 1210', 'CS 2100']}, {'OR'...
# 9                                                None
# 10                                               None
# 12                                            CS 1210
# 14                                            CS 2100
# 16                               {'AND': ['CS 2100']}
# 18                   {'OR': ['CS 1640', 'MATH 2055']}
# 20                                            CS 2240
# 22                               {'AND': ['CS 1210']}
# 24                                            CS 2240
# 26                                            CS 2210
# 27    {'OR': ['STAT 1110', 'STAT 1410', 'STAT 2430']}
# 28                                               None
# 30                                               None
# 31                                               None
# 33                    {'AND': ['CS 2300', 'CS 2210']}
# 35                                            CS 2240
# 36                                            CS 2300
# 37                                               None
# 38                    {'AND': ['CS 2240', 'CS 2250']}
# 39                    {'AND': ['CS 2240', 'CS 2250']}
# 40                   {'OR': ['CMPE 2210', 'CS 2210']}
# 41                                            CS 2240
# 43                    {'AND': ['CS 2240', 'CS 2250']}
# 44                                {'OR': ['CS 1080']}
# 45  {'AND': [{'OR': ['STAT 2510', 'STAT 5510']}, {...
# 47                                            CS 2240
# 48  {'AND': ['MATH 2248', {'OR': ['MATH 2522', 'MA...
# 49                               {'AND': ['CS 2300']}
# 50  {'AND': ['CS 1210', {'OR': ['STAT 1410', 'STAT...
# 52                                               None
# 54                                            CS 2240
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
#
#                                    other_requirements uncertain
# 0                  [Open to Degree and PACE students]     False
# 2              [Open to CS, CSIS, and DS majors only]     False
# 3                  [Open to Degree and PACE students]     False
# 5                  [Open to Degree and PACE students]     False
# 7   [Computer Science or Computer Science & Inform...     False
# 8                  [Open to Degree and PACE students]     False
# 9                  [Open to Degree and PACE students]     False
# 10                   [Instructor permission required]     False
# 12                                                 []     False
# 14                                                 []     False
# 16                       [minimum Sophomore standing]     False
# 18                 [Open to Degree and PACE students]     False
# 20                 [Open to Degree and PACE students]     False
# 22  [minimum Sophomore standing, Open to degree an...     False
# 24                                                 []     False
# 26                 [Open to Degree and PACE students]     False
# 27                                                 []     False
# 28  [Instructor permission, Open to Degree and PAC...     False
# 30                 [Offered at department discretion]     False
# 31                               [Department consent]     False
# 33                 [Open to degree and PACE students]     False
# 35  [Familiarity with basic data structures, algor...     False
# 36                 [Open to Degree and PACE students]     False
# 37  [Junior standing, programming experience, Inst...     False
# 38                 [Open to degree and PACE students]     False
# 39                                                 []     False
# 40                 [Open to Degree and PACE students]     False
# 41                                                 []     False
# 43                 [Open to degree and PACE students]     False
# 44  [Minimum Junior standing, completion of WIL1, ...     False
# 45                 [Open to Degree and PACE students]     False
# 47                                                 []     False
# 48                                                 []     False
# 49  [Senior standing, Open to Degree and PACE stud...     False
# 50                 [Open to degree and PACE students]     False
# 52  [Senior standing in Computer Science, CS or CS...     False
# 54                                                 []     False
# 56                 [Offered at department discretion]     False
# 57                 [Offered at department discretion]     False
# 58                 [Offered at department discretion]     False
# 59  [Instructor permission required, Offered at de...     False
# 60                 [Offered at department discretion]     False
# 61  [Instructor permission required, Offered at de...     False
# 62                               [Department consent]     False
# 64                               [Department consent]     False
# 65  [Graduate student, Open to degree and PACE stu...     False
# 66         [Graduate student, Graduate students only]     False
# 67  [Graduate student, Open to degree and PACE stu...     False
# 68  [Proficiency in Python programming, familiarit...     False
# 69                        [Graduate student standing]     False

# %%
# move Independent Studies
# contains IS:, IS-, Ind Stdy, or Independent Study
import re
remove_list = ['IS:', 'IS-', 'Ind Stdy', 'Independent Study']
pattern = '|'.join(re.escape(s) for s in remove_list)

# Select only the independent study rows
independent_studies = all_courses[all_courses['title'].str.contains(pattern, case=True, na=False)]

# Export to CSV
independent_studies.to_csv('independent_studies.csv', index=False)

# Drop from all courses
all_courses = all_courses[~all_courses['title'].str.contains(pattern, case=True, na=False)]

# %%
all_courses[0:50]
# Out:
#    course_code                 section                           title  \
# 0      CS 1080    Section A, CRN 91695           Intro to Web Site Dev
# 2      CS 1210    Section F, CRN 92166      Comp Prog I: for CS majors
# 3      CS 1210    Section B, CRN 90147          Computer Programming I
# 5      CS 1320    Section A, CRN 94171     Puzzles, Games & Algorithms
# 7      CS 1500    Section A, CRN 90913       Seminar for New CS Majors
# 8      CS 1640    Section A, CRN 90230             Discrete Structures
# 9      CS 1870    Section A, CRN 92324           Intro to Data Science
# 10     CS 1994                     NaN          Teaching Assistantship
# 12     CS 2100                     NaN        Intermediate Programming
# 14     CS 2210                     NaN           Computer Organization
# 16     CS 2240                     NaN         Data Struc & Algorithms
# 18     CS 2250                     NaN       Computability& Complexity
# 20     CS 2300                     NaN            Advanced Programming
# 22     CS 2500    Section A, CRN 94648       Intro to Database Systems
# 24     CS 2510                     NaN   Intro Artificial Intelligence
# 26     CS 2660  Section OL1, CRN 13197        Cybersecurity Principles
# 27     CS 2870                     NaN          Basics of Data Science
# 28     CS 2920    Section A, CRN 12182               SL:Girls Who Code
# 31     CS 2994                     NaN          Teaching Assistantship
# 33     CS 3010    Section A, CRN 90238               Operating Systems
# 35     CS 3040    Section A, CRN 93083                Database Systems
# 36     CS 3050    Section A, CRN 11825            Software Engineering
# 37     CS 3060    Section A, CRN 10577           Evolutionary Robotics
# 38     CS 3110    Section A, CRN 92684                    Data Privacy
# 39     CS 3120    Section A, CRN 15536  Secure Distributed Computation
# 40     CS 3220    Section A, CRN 10129           Computer Architecture
# 41     CS 3240                     NaN     Algorithm Design & Analysis
# 43     CS 3250    Section A, CRN 95707           Programming Languages
# 44     CS 3280    Section A, CRN 95641      Human-Computer Interaction
# 45     CS 3540    Section A, CRN 94179                Machine Learning
# 47     CS 3650    Section A, CRN 15379               Computer Networks
# 48     CS 3737    Section A, CRN 93742     Intro to Numerical Analysis
# 49     CS 3750    Section A, CRN 90889          Mobile App Development
# 50     CS 3870    Section A, CRN 92312       Data Science I - Pinnacle
# 52     CS 3920                     NaN                  Senior Seminar
# 54     CS 3930    Section A, CRN 92314    Computing Career Preparation
# 62     CS 3994    Section A, CRN 14971          Teaching Assistantship
# 64     CS 4996                     NaN     Undergraduate Honors Thesis
# 65     CS 5040    Section A, CRN 94078             Gr Database Systems
# 66     CS 5060    Section A, CRN 13202  Advanced Evolutionary Robotics
# 67     CS 5110    Section A, CRN 93798           Advanced Data Privacy
# 68     CS 5120    Section A, CRN 15537   Adv Secure Distributed Comput
# 69     CS 5220    Section A, CRN 13210  Advanced Computer Architecture
# 70     CS 5240                     NaN       Advanced Algorithm Design
# 72     CS 5540    Section A, CRN 94180       Advanced Machine Learning
# 74     CS 5870    Section A, CRN 93777     Data Science I - Experience
# 76     CS 5990    Section A, CRN 95644     Natural Language Processing
# 77     CS 6020    Section A, CRN 92171      Modeling Complex Systems I
# 78     CS 6021    Section A, CRN 15785     Modeling Complex Systems II
# 79     CS 6040    Section A, CRN 15231                     Data Mining
#
#          credit_hours                                       meeting_info  \
# 0                   3  TTh 4:25pm-5:40pm in JAMES M JEFFORDS HALL 127...
# 2                   3  TTh 2:50pm-4:05pm in MARSH LIFE SCI 105 (8/25 ...
# 3                   3  TTh 8:30am-9:45am in VOTEY BLDG 207 (8/25 to 1...
# 5                   3  MWF 10:50am-11:40am in VOTEY BLDG 303 (8/25 to...
# 7                   1   F 2:20pm-3:10pm in VOTEY BLDG 105 (8/25 to 12/5)
# 8                   3  MWF 1:10pm-2pm in PERKINS BUILDING 003 (8/25 t...
# 9                   3    MWF 1:10pm-2pm in VOTEY BLDG 209 (8/25 to 12/5)
# 10  Varies by section                                                NaN
# 12  Varies by section                                                NaN
# 14                  3                                                NaN
# 16                  3                                                NaN
# 18                  3                                                NaN
# 20                  3                                                NaN
# 22                  3  MW 3:30pm-4:45pm in INNOVATION HALL E204 (8/25...
# 24                  3                                                NaN
# 26                  3                                                NaN
# 27                  3                                                NaN
# 28                  1                                                NaN
# 31             1 to 3                                                NaN
# 33                  3  MWF 12pm-12:50pm in VOTEY BLDG 207 (8/25 to 12/5)
# 35                  3  MWF 8:30am-9:20am in MARSH LIFE SCI 105 (8/25 ...
# 36                  3         MWF 3:30pm-4:20pm UNASSIGNED (1/12 to 5/1)
# 37                  3         TTh 8:30am-9:45am UNASSIGNED (1/12 to 5/1)
# 38                  3    MWF 1:10pm-2pm in DEWEY HALL 314 (8/25 to 12/5)
# 39                  3       MWF 10:50am-11:40am UNASSIGNED (1/12 to 5/1)
# 40                  3            MWF 1:10pm-2pm UNASSIGNED (1/12 to 5/1)
# 41                  3                                                NaN
# 43                  3  TTh 4:25pm-5:40pm in INNOVATION HALL E210 (8/2...
# 44                  3  TTh 1:15pm-2:30pm in LAFAYETTE HALL L111 (8/25...
# 45                  3  TTh 1:15pm-2:30pm in VOTEY BLDG 207 (8/25 to 1...
# 47                  3         TTh 2:50pm-4:05pm UNASSIGNED (1/12 to 5/1)
# 48                  3  TTh 2:50pm-4:05pm in PERKINS BUILDING 102 (8/2...
# 49                  3  MWF 3:30pm-4:20pm in JAMES M JEFFORDS HALL 112...
# 50                  3  TTh 4:25pm-5:40pm in INNOVATION HALL E430 (8/2...
# 52                  1                                                NaN
# 54                  1  W 5:05pm-5:55pm in MORRILL HALL 010 (8/25 to 1...
# 62                  1                                                NaN
# 64                  3                                                NaN
# 65                  3  MWF 8:30am-9:20am in MARSH LIFE SCI 105 (8/25 ...
# 66                  3         TTh 8:30am-9:45am UNASSIGNED (1/12 to 5/1)
# 67                  3    MWF 1:10pm-2pm in DEWEY HALL 314 (8/25 to 12/5)
# 68                  3       MWF 10:50am-11:40am UNASSIGNED (1/12 to 5/1)
# 69                  3            MWF 1:10pm-2pm UNASSIGNED (1/12 to 5/1)
# 70                  3                                                NaN
# 72                  3  TTh 1:15pm-2:30pm in VOTEY BLDG 207 (8/25 to 1...
# 74                  3  TTh 4:25pm-5:40pm in INNOVATION HALL E432 (8/2...
# 76                  3  TTh 10:05am-11:20am in LAFAYETTE HALL L107 (8/...
# 77                  3  TTh 2:50pm-4:05pm in VOTEY BLDG 209 (8/25 to 1...
# 78                  3         TTh 2:50pm-4:05pm UNASSIGNED (1/12 to 5/1)
# 79                  3         TTh 8:30am-9:45am UNASSIGNED (1/12 to 5/1)
#
#                  instructor  \
# 0              Murat Gungor
# 2             Sami Connolly
# 3             Sami Connolly
# 5                 Lisa Dion
# 7             Sami Connolly
# 8            Jeffrey Jewell
# 9              Roger Tenore
# 10                      NaN
# 12            Jackie Horton
# 14          Clayton Cafiero
# 16                      NaN
# 18                      NaN
# 20                Lisa Dion
# 22            Jackie Horton
# 24          Clayton Cafiero
# 26               James Eddy
# 27             Jacob Martin
# 28                Lisa Dion
# 31                      NaN
# 33           Jason Hibbeler
# 35                Byung Lee
# 36           Jason Hibbeler
# 37           Joshua Bongard
# 38                 Joe Near
# 39                 Joe Near
# 40           Jason Hibbeler
# 41                      NaN
# 43          Jennifer Paykin
# 44            Yuanyuan Feng
# 45             Safwan Wshah
# 47             Chris Skalka
# 48                   Jun Yu
# 49           Jason Hibbeler
# 50            Alice Patania
# 52                Lisa Dion
# 54              Jill Duprey
# 62            Jackie Horton
# 64                      NaN
# 65                Byung Lee
# 66           Joshua Bongard
# 67                 Joe Near
# 68                 Joe Near
# 69           Jason Hibbeler
# 70                      NaN
# 72             Safwan Wshah
# 74                Sam Zhang
# 76           Juniper Lovato
# 77  Laurent Hebert-Dufresne
# 78  Laurent Hebert-Dufresne
# 79                Byung Lee
#
#                                           description  \
# 0   Provides a strong foundation in HTML, CSS, ima...
# 2   Introduction to algorithmic problem solving an...
# 3   Introduction to algorithmic problem solving an...
# 5   Introductory computer science through explorat...
# 7   A fun and accessible breadth-first introductio...
# 8   Introduction to analytic and formal methods of...
# 9   Basic techniques of data harvesting and cleani...
# 10  Assist in instruction of undergraduate compute...
# 12  Intermediate programming concepts including co...
# 14  Introduction to computer system organization i...
# 16  Design and implementation of linear structures...
# 18  Formal languages and expressiveness. Turing co...
# 20  Builds programming maturity and proficiency th...
# 22  Serves as a foundational course in modern data...
# 24  An introduction to artificial intelligence inc...
# 26  Introduction to cybersecurity, fundamental sec...
# 27  Basic data science techniques, from import to ...
# 28  Service learning experience that benefits the ...
# 31  Undergraduate student service as a teaching as...
# 33  Supervisory and control software for multiprog...
# 35  Techniques for processing very large collectio...
# 36  Treatment of software engineering problems and...
# 37  Exploration of the automated design of autonom...
# 38  Explores the research field of data privacy, i...
# 39  Techniques for secure computation involving mu...
# 40  Architecture of computing systems. Control uni...
# 41  Comprehensive study of algorithms including gr...
# 43  Principles of programming language design and ...
# 44  Covers the foundational theories and methods i...
# 45  Introduction to machine learning algorithms, t...
# 47  Introduction to the theoretical and pragmatic ...
# 48  Error analysis, root-finding, interpolation, l...
# 49  A projects-based course focusing on software d...
# 50  Data harvesting, cleaning, and summarizing; wo...
# 52  Oral presentations that pertain to the ethical...
# 54  Seminar to help students develop necessary ski...
# 62  Undergraduate student service as a teaching as...
# 64  College honors thesis or other department/prog...
# 65  Covers the theory and practice of database des...
# 66  Explores the automated design of autonomous ma...
# 67  Explores the research field of data privacy, i...
# 68  Techniques for secure computation involving mu...
# 69  Provides a thorough and sophisticated examinat...
# 70  Studies how to design and analyze computer pro...
# 72  Provides a broad introduction to machine learn...
# 74  Data harvesting, cleaning, and summarizing; wo...
# 76  See Schedule of Courses for specific titles. S...
# 77  Integrative breadth-first introduction to comp...
# 78  Deep dive in state-of-the-art mathematical and...
# 79  Introduces the field of data mining, including...
#
#                                   section_description  \
# 0   Lays a foundation in website coding with HTML,...
# 2   Introduction to programming and computer scien...
# 3            Introduction to programming with Python.
# 5   In this course, you will explore computational...
# 7   This course is intended to introduce new Compu...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  You will learn the common data structures for ...
# 18                                                NaN
# 20  This project-based course is separated into fo...
# 22  This course will serve as a foundational cours...
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  This is for students who help facilitate the U...
# 31                                                NaN
# 33  CS 3010 will provide a broad overview of opera...
# 35  Theory and practice of database design and app...
# 36  CS 3050 will present a broad overview of the m...
# 37                                                NaN
# 38  How can we learn from sensitive data collected...
# 39  Techniques for secure computation involving mu...
# 40  CS 3220 will provide a thorough and sophistica...
# 41                                                NaN
# 43  The focus of this course is on the design of p...
# 44  This course fulfills WIL2 (Writing and Informa...
# 45  This course offers an introduction to advanced...
# 47  Description: Introduction to the theoretical a...
# 48  This course covers introductory materials on n...
# 49  CS 3750 will provide a broad overview of iOS a...
# 50                                                NaN
# 52  This course explores ethics at the intersectio...
# 54                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Theory and practice of database design and app...
# 66                                                NaN
# 67  How can we learn from sensitive data collected...
# 68  Techniques for secure computation involving mu...
# 69  CS 5220 will provide a thorough and sophistica...
# 70                                                NaN
# 72  This course offers an introduction to advanced...
# 74  Extracting meaning from data remains one of th...
# 76  This course provides a comprehensive, breadth-...
# 77  Integrative breadth-first introduction to comp...
# 78                                                NaN
# 79                                                NaN
#
#                                  section_expectations  \
# 0       Assumes no prior experience with programming.
# 2   Assumes no prior experience with programming. ...
# 3       Assumes no prior experience with programming.
# 5   This course is taught in an active learning st...
# 7   You will be expected to attend each lecture pe...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  This class is run lecture-style with practice ...
# 18                                                NaN
# 20  Every three-week module will be themed and wil...
# 22          Completion of CS1210. Sophomore Standing.
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  You will be expected to attend the club every ...
# 31                                                NaN
# 33  Students will learn concepts by creating sever...
# 35  Lecture course. 6 to 8 hours of work expected ...
# 36  There will be three individual in-class coding...
# 37                                                NaN
# 38  This course will be structured around lectures...
# 39  By the end of this course, you will be able to...
# 40  Students will do written exercises; create sof...
# 41                                                NaN
# 43  Prerequisites: CS 2240, CS 2250. The main cour...
# 44  The course materials include:\nTextbook: Norma...
# 45  Weekly assignments, Term Project and two Mid-t...
# 47  This course is taught in a lecture and discuss...
# 48  This course is in lecture format. Homework (or...
# 49  The instructor will discuss and elaborate on t...
# 50                                                NaN
# 52  You will be expected to attend class regularly...
# 54                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Lecture course. 6 to 8 hours of work expected ...
# 66                                                NaN
# 67  This course will be structured around lectures...
# 68  By the end of this course, you will be able to...
# 69  Students will do written exercises; create sof...
# 70                                                NaN
# 72  Weekly assignments, Term Project and two Mid-t...
# 74  Learning objectives In this course students wi...
# 76  This course will be structured around lectures...
# 77  This course combines lecture and discussion fo...
# 78                                                NaN
# 79                                                NaN
#
#                                            evaluation  \
# 0   Quizzes, Active Learning Exercises, Lab Exerci...
# 2                                                 NaN
# 3   Weekly homework, lab and active learning exerc...
# 5   This course is taught using a points-based sys...
# 7   Your final grade will be based on pre-class wr...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 12                                                NaN
# 14                                                NaN
# 16  Your final grade will be based on quizzes, pro...
# 18                                                NaN
# 20  This course uses a point-based grading system,...
# 22                                                NaN
# 24                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  You will be evaluated based on attendance, com...
# 31                                                NaN
# 33  Course grades will be based on the midterm and...
# 35  Weekly homework, including written and program...
# 36  Course grades will be based on in-class coding...
# 37                                                NaN
# 38  Your grade for the course will be determined a...
# 39  Your grade for the course will be determined a...
# 40  Student grades will be based on the exams, the...
# 41                                                NaN
# 43  Homework for the course will be a combination ...
# 44  Evaluations:\nStudent grades will be based on:...
# 45  • Assigned homework (30%)\n• Term Project (30%...
# 47  - Homework and programming assigments: 60%\n -...
# 48  Grades are based on midterm and final exams, q...
# 49  Student grades will be based on the individual...
# 50                                                NaN
# 52  Grading is based on participating in debates a...
# 54                                                NaN
# 62                                                NaN
# 64                                                NaN
# 65  Weekly homework, including written and program...
# 66                                                NaN
# 67  Your grade for the course will be determined a...
# 68  Your grade for the course will be determined a...
# 69  Student grades will be based on the exams, the...
# 70                                                NaN
# 72  • Assigned homework (25%)\n• Term Project (35%...
# 74  Grades 35% for homework, 15% for quizzes, 15% ...
# 76  Grades will be determined as follows:\nHomewor...
# 77  Grades are based on class participation, biwee...
# 78                                                NaN
# 79                                                NaN
#
#                                          soc_comments              semester  \
# 0                    Open to Degree and PACE students  Fall and Spring 2025
# 2                Open to CS, CSIS, and DS majors only             Fall 2025
# 3                    Open to Degree and PACE students  Fall and Spring 2025
# 5                    Open to Degree and PACE students  Fall and Spring 2025
# 7               CS, CSIS, or Data Science majors only             Fall 2025
# 8   Prereqs enforced by the system: (CS 1210 or 21...             Fall 2025
# 9   Cross-listed with STAT 1870 A;\nTotal combined...             Fall 2025
# 10                                  Varies by section  Fall and Spring 2025
# 12                                  Varies by section  Fall and Spring 2025
# 14                                  Varies by section  Fall and Spring 2025
# 16                                  Varies by section  Fall and Spring 2025
# 18  Prereqs enforced by the system: CS 1640 or MAT...  Fall and Spring 2025
# 20  Prereqs enforced by the system: CS 2240;\nOpen...  Fall and Spring 2025
# 22  Prereqs enforced by the system: CS 1210\nOpen ...  Fall and Spring 2025
# 24            Prereqs enforced by the system: CS 2240  Fall and Spring 2025
# 26  Prereqs enforced by the system: CS 2210 with a...           Spring 2026
# 27                                  Varies by section             Fall 2025
# 28  Instructor permission required;\nOpen to Degre...  Fall and Spring 2025
# 31                                  Varies by section  Fall and Spring 2025
# 33  Prereqs enforced by the system: CS 2210 and CS...  Fall and Spring 2025
# 35  Prereqs enforced by the system: CS 2240;\nColo...             Fall 2025
# 36  Prereqs enforced by the system: CS 2300;\nProj...           Spring 2026
# 37  Prereq: Junior standing and programming experi...           Spring 2026
# 38  Prereqs enforced by the system: CS 2240 and CS...             Fall 2025
# 39  Prereqs enforced by the system: CS 2240 and CS...           Spring 2026
# 40  Prereqs enforced by the system: CS 2210 or CMP...           Spring 2026
# 41                                  Varies by section  Fall and Spring 2025
# 43  Prereqs enforced by the system: CS 2240, CS 22...             Fall 2025
# 44  Prereq: CS 1080 or equivalent experience;\nmin...             Fall 2025
# 45  Prereqs enforced by the system: STAT 2510 or 5...  Fall and Spring 2025
# 47  Cross-listed with CMPE 3650 A; Total combined ...           Spring 2026
# 48  Prereqs enforced by the system: CS 1210 and MA...             Fall 2025
# 49  Prereqs enforced by the system: CS 2300;\nOpen...             Fall 2025
# 50  Prereqs enforced by the system: CS 1210 and\n(...  Fall and Spring 2025
# 52                    CS or CSIS senior students only  Fall and Spring 2025
# 54            Prereqs enforced by the system: CS 2240  Fall and Spring 2025
# 62                                                NaN  Fall and Spring 2025
# 64                                  Varies by section             Fall 2025
# 65  Colocated with CS 3040 A;\nTotal combined enro...             Fall 2025
# 66  Graduate students only;\nCo-located with CS 30...           Spring 2026
# 67  Prereq: Graduate student;\nCo-located with CS ...             Fall 2025
# 68  Familiarity with topics of data structures and...           Spring 2026
# 69  Familiarity with topics of computer organizati...           Spring 2026
# 70                                  Varies by section  Fall and Spring 2025
# 72  Prereqs enforced by the system:STAT 2510 & Mat...  Fall and Spring 2025
# 74  Prereqs:Graduate student or instructor permiss...  Fall and Spring 2025
# 76  Junior standing and programming experience in ...             Fall 2025
# 77  Graduate standing only;\nOpen to Degree and PA...             Fall 2025
# 78  Prereqs enforced by the system: CS 6020 or CSY...           Spring 2026
# 79  Prereqs enforced by the system:\nComputer Scie...           Spring 2026
#
#                                         prerequisites  \
# 0                                                None
# 2                                                None
# 3                                                None
# 5                                                None
# 7                                                None
# 8   {'AND': [{'OR': ['CS 1210', 'CS 2100']}, {'OR'...
# 9                                                None
# 10                                               None
# 12                                            CS 1210
# 14                                            CS 2100
# 16                               {'AND': ['CS 2100']}
# 18                   {'OR': ['CS 1640', 'MATH 2055']}
# 20                                            CS 2240
# 22                               {'AND': ['CS 1210']}
# 24                                            CS 2240
# 26                                            CS 2210
# 27    {'OR': ['STAT 1110', 'STAT 1410', 'STAT 2430']}
# 28                                               None
# 31                                               None
# 33                    {'AND': ['CS 2300', 'CS 2210']}
# 35                                            CS 2240
# 36                                            CS 2300
# 37                                               None
# 38                    {'AND': ['CS 2240', 'CS 2250']}
# 39                    {'AND': ['CS 2240', 'CS 2250']}
# 40                   {'OR': ['CMPE 2210', 'CS 2210']}
# 41                                            CS 2240
# 43                    {'AND': ['CS 2240', 'CS 2250']}
# 44                                {'OR': ['CS 1080']}
# 45  {'AND': [{'OR': ['STAT 2510', 'STAT 5510']}, {...
# 47                                            CS 2240
# 48  {'AND': ['MATH 2248', {'OR': ['MATH 2522', 'MA...
# 49                               {'AND': ['CS 2300']}
# 50  {'AND': ['CS 1210', {'OR': ['STAT 1410', 'STAT...
# 52                                               None
# 54                                            CS 2240
# 62                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
# 70                                               None
# 72  {'AND': ['STAT 2510', {'OR': ['MATH 2522', 'MA...
# 74  {'AND': ['CS 1210', {'OR': ['STAT 1410', 'STAT...
# 76                                               None
# 77                                               None
# 78                   {'OR': ['CS 6020', 'CSYS 6020']}
# 79                                               None
#
#                                    other_requirements uncertain
# 0                  [Open to Degree and PACE students]     False
# 2              [Open to CS, CSIS, and DS majors only]     False
# 3                  [Open to Degree and PACE students]     False
# 5                  [Open to Degree and PACE students]     False
# 7   [Computer Science or Computer Science & Inform...     False
# 8                  [Open to Degree and PACE students]     False
# 9                  [Open to Degree and PACE students]     False
# 10                   [Instructor permission required]     False
# 12                                                 []     False
# 14                                                 []     False
# 16                       [minimum Sophomore standing]     False
# 18                 [Open to Degree and PACE students]     False
# 20                 [Open to Degree and PACE students]     False
# 22  [minimum Sophomore standing, Open to degree an...     False
# 24                                                 []     False
# 26                 [Open to Degree and PACE students]     False
# 27                                                 []     False
# 28  [Instructor permission, Open to Degree and PAC...     False
# 31                               [Department consent]     False
# 33                 [Open to degree and PACE students]     False
# 35  [Familiarity with basic data structures, algor...     False
# 36                 [Open to Degree and PACE students]     False
# 37  [Junior standing, programming experience, Inst...     False
# 38                 [Open to degree and PACE students]     False
# 39                                                 []     False
# 40                 [Open to Degree and PACE students]     False
# 41                                                 []     False
# 43                 [Open to degree and PACE students]     False
# 44  [Minimum Junior standing, completion of WIL1, ...     False
# 45                 [Open to Degree and PACE students]     False
# 47                                                 []     False
# 48                                                 []     False
# 49  [Senior standing, Open to Degree and PACE stud...     False
# 50                 [Open to degree and PACE students]     False
# 52  [Senior standing in Computer Science, CS or CS...     False
# 54                                                 []     False
# 62                               [Department consent]     False
# 64                               [Department consent]     False
# 65  [Graduate student, Open to degree and PACE stu...     False
# 66         [Graduate student, Graduate students only]     False
# 67  [Graduate student, Open to degree and PACE stu...     False
# 68  [Proficiency in Python programming, familiarit...     False
# 69                        [Graduate student standing]     False
# 70  [Familiarity with data structures and elementa...     False
# 72  [Graduate student, Open to Degree and PACE stu...     False
# 74  [Graduate student or Instructor permission, Op...     False
# 76  [Junior standing, programming experience in Py...     False
# 77  [Graduate standing, Open to Degree and PACE st...     False
# 78                                                 []     False
# 79                [Computer Science Graduate student]     False

# %%
all_courses.to_csv('all_courses.csv', index=False)
